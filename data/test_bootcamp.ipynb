# %%
   
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from buying_or_selling import get_data_from_mongodb
get_data_from_mongodb()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from buying_or_selling import get_data_from_mongodb
#       2 get_data_from_mongodb()
#
# ModuleNotFoundError: No module named 'buying_or_selling'

# %%
from buying_or_selling import result_local,result_mongo
actual    = np.array(result_mongo)
predicted = np.array(result_local)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from buying_or_selling import result_local,result_mongo
#       2 actual    = np.array(result_mongo)
#       3 predicted = np.array(result_local)
#
# ModuleNotFoundError: No module named 'buying_or_selling'

# %%
cm = confusion_matrix(actual,predicted)

# %%
sns.heatmap(cm, 
			annot=True,
			fmt='g', 
			xticklabels=['Dog','Not Dog'],
			yticklabels=['Dog','Not Dog'])
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix',fontsize=17)
plt.show()
